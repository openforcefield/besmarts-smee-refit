# %%
import datasets
import tqdm

# %% [markdown]
# ## Load dataset
#
# These are [Huggingface dataset](https://huggingface.co/docs/datasets/en/index) formats.

# %%
opt_dataset = datasets.Dataset.load_from_disk("../data/additional-optimizations/")
td_dataset = datasets.Dataset.load_from_disk("../data/additional-torsiondrives/")

# %% [markdown]
# Datasets are represented with the features in each entry.

# %%
opt_dataset
# Out:
# Dataset({
#     features: ['smiles', 'coords', 'energy', 'forces'],
#     num_rows: 70
# })

# %% [markdown]
# Datasets can be indexed to get a single entry. "coords", "forces", etc. are stored as flat lists of floats.

# %%
opt_dataset[0]
# Out:
# {'smiles': '[H:17][c:1]1[c:2]([c:5]([c:9]([c:8]([c:4]1[H:20])[c:10]2[c:6]([c:3]([c:7]([c:11](=[O:15])[n:14]2[C:12]([H:24])([H:25])[H:26])[H:23])[H:19])[H:22])[O:16][C:13]([H:27])([H:28])[H:29])[H:21])[H:18]',
#  'coords': [-2.429097601086157,
#   -4.995734076091361,
#   5.279949289173572,
#   -1.4927028614970528,
#   -4.969878833032298,
#   6.313283057490595,
#   -1.7725006246161668,
#   -0.5189687735923793,
#   1.6009539610385115,
#   -2.247461979620605,
#   -4.159604022426994,
#   4.172769570744676,
#   -0.38466058273334747,
#   -4.115854293359497,
#   6.251594902508013,
#   -1.9333702569868894,
#   -1.4028490611584157,
#   2.7018932656017056,
#   -0.6955642015756051,
#   -0.6374878174592984,
#   0.7671004023768058,
#   -1.1450532229998112,
#   -3.3048529745574973,
#   4.08185260086658,
#   -0.21036471460187214,
#   -3.2807783690358603,
#   5.1415423097198305,
#   -1.002708576933281,
#   -2.391834366260054,
#   2.9167438933540053,
#   0.30720990737475856,
#   -1.6608091536936738,
#   0.9680378916896591,
#   1.0356941877630836,
#   -3.6276665354563615,
#   2.2018308330263867,
#   1.8045151561116768,
#   -2.330830022342404,
#   6.028561914211468,
#   0.062159705441746434,
#   -2.5406012081457687,
#   2.0564549717928475,
#   1.3149496940928658,
#   -1.8180146646400603,
#   0.26717523739914295,
#   0.8264578195992346,
#   -2.4045003477497913,
#   4.994302609247868,
#   -3.2879780771225624,
#   -5.658493444983325,
#   5.329095627003897,
#   -1.6174342179365262,
#   -5.614002658450074,
#   7.1797723733777215,
#   -2.508141790440771,
#   0.26454820902265785,
#   1.432905579077897,
#   -2.9622733766111344,
#   -4.171707063572407,
#   3.354518710453695,
#   0.32510026950066656,
#   -4.104046876107556,
#   7.070742205314529,
#   -2.7543959182718734,
#   -1.2939725720062427,
#   3.400314268191367,
#   -0.5340726644620868,
#   0.0267801736576004,
#   -0.07513809700837873,
#   0.6051872581121523,
#   -4.4273050978067525,
#   2.801638187427888,
#   1.9469100648279618,
#   -3.257782764724125,
#   2.6778548685709094,
#   1.2920614876071967,
#   -3.9944123127490543,
#   1.2079964639249465,
#   2.523906021445296,
#   -1.5797417230562216,
#   5.701161656377999,
#   2.315514186614844,
#   -3.291784861302583,
#   6.163032893656377,
#   1.355428614764815,
#   -2.016265101175405,
#   6.978141542803798,
#   -1.992795896634442,
#   -5.5699276093072,
#   4.9279430484618905,
#   -1.4094271284576039,
#   -5.228955013799289,
#   6.147967897300436,
#   0.3684544779122726,
#   -2.647729776685729,
#   0.4666801904616354,
#   -1.7367352811569141,
#   -4.777880338081819,
#   3.803074128102622,
#   -0.572117634122512,
#   -4.1111949971016895,
#   6.251337907781364,
#   0.06985275768431178,
#   -3.4265810871406686,
#   1.617123418476913,
#   -0.011022853987441046,
#   -1.3360531371955715,
#   0.39881569475956974,
#   -0.9128746607029118,
#   -3.6514107602767756,
#   3.881403625778443,
#   -0.31903537338201765,
#   -3.3243089900078493,
#   5.1215248812927365,
#   -0.6191776968305401,
#   -2.854899066938318,
#   2.6604778378413654,
#   -0.728683223890412,
#   -0.6994810939648464,
#   1.481877144303146,
#   -1.8428997172047499,
#   -0.9198680452319045,
#   3.6349064575118732,
#   1.1205270786099888,
#   -1.8406390044809406,
#   6.336074513822694,
#   -1.039339160761876,
#   -1.545969181907066,
#   2.5799200988041857,
#   -1.086659298649056,
#   0.4849980093390246,
#   1.4996229674523731,
#   0.4925973020983815,
#   -2.2262948065843586,
#   5.115921525976743,
#   -2.641791912281023,
#   -6.437057209108795,
#   4.849050505939085,
#   -1.599051437109063,
#   -5.832233431227574,
#   7.031912107073227,
#   0.9148344338237097,
#   -3.100285435474245,
#   -0.3579228755649693,
#   -2.188791507057798,
#   -5.023666964743398,
#   2.8460511579411807,
#   -0.12023414455720427,
#   -3.870697746027091,
#   7.206784655159181,
#   0.4045004939190886,
#   -4.452911179088234,
#   1.7087487072620369,
#   0.21058801837016286,
#   -0.7083029204897866,
#   -0.4576419120044041,
#   -1.2093846211605785,
#   -0.3044223189115257,
#   4.278110083394292,
#   -2.332291994671997,
#   -1.6899380434636202,
#   4.228378342838683,
#   -2.5842298318113794,
#   -0.2745980164048676,
#   3.16396519965617,
#   1.7062990043423356,
#   -0.9522784690896392,
#   6.098324236731503,
#   1.7870454123117483,
#   -2.6288083945471197,
#   6.706059864441726,
#   0.37889422078062046,
#   -1.5940461161979653,
#   7.1053524135521355],
#  'energy': [-444615.5625, -444615.5625],
#  'forces': [0.14214000599723142,
#   0.08584365154678675,
#   0.019057604398884244,
#   -0.036934056775204664,
#   -0.06867586041811254,
#   0.06829463073303348,
#   -0.007985665588522697,
#   0.008843459864547897,
#   0.01987881563550947,
#   -0.08988444501509842,
#   0.033441482214305145,
#   -0.11472354779102824,
#   -0.00019192075589385008,
#   0.02679529629762236,
#   -0.018938616989033017,
#   -0.013518108188484167,
#   -0.026017677780613615,
#   -0.01230549739846869,
#   0.01754114447472838,
#   0.008190153957465019,
#   -0.028872445244838372,
#   -0.03943132222863539,
#   -0.04106714408628231,
#   0.019060019491387473,
#   0.042595254083174994,
#   -0.0062061324474252015,
#   0.012247958239163319,
#   0.03606019406081994,
#   0.049566074538167464,
#   0.022549208012351666,
#   -0.0596514440524081,
#   0.04630502842051799,
#   -0.013971454545087955,
#   0.005336926323861236,
#   0.007263467283907373,
#   0.014921935595926182,
#   0.02569128767085684,
#   -0.012571060433852971,
#   -0.0037171126222982675,
#   0.02909730618773524,
#   -0.11539430074921914,
#   -0.020360813187337776,
#   -0.031191251241948798,
#   0.003935086056624218,
#   0.03447350634342404,
#   -0.06672579573716135,
#   0.01036429075520162,
#   0.01846442459424366,
#   0.011033928992822462,
#   0.016008751634018534,
#   -0.0035874646066461173,
#   0.012261292921383997,
#   -0.001937269236123517,
#   0.014271519496777447,
#   -0.005665689802948236,
#   -0.0013113360181446336,
#   -0.0017573470392118356,
#   -0.008103236519175374,
#   0.0003630626328140784,
#   -0.011154264616275836,
#   0.00018226958504502906,
#   -0.008271883268072157,
#   0.0005476442616225475,
#   0.0032162537997915647,
#   0.013281711813350493,
#   0.006992570541796278,
#   -0.013406607345750951,
#   0.011311510797093777,
#   0.0007295423423199973,
#   -0.004483731572752433,
#   -0.008808340205240807,
#   -0.022062148444720455,
#   -0.003359703066509128,
#   -0.006235891976587219,
#   0.011549235799926491,
#   0.0108592481781628,
#   0.012766241761946472,
#   -0.00048211319109352934,
#   0.0012654347954386966,
#   -0.0020721440794414566,
#   -0.0027461180827461885,
#   -0.006543315666893096,
#   -0.00035506605686513735,
#   0.0012444373633765749,
#   0.002674662586496689,
#   0.005495966368589813,
#   -0.0025287615207569315,
#   0.021870134615072576,
#   0.05894687309445447,
#   -0.059048893119672666,
#   0.03591861385099933,
#   0.011906871236102616,
#   0.07522374467203968,
#   -0.015971128108747464,
#   -0.017756017039232158,
#   0.0016769132775093004,
#   -0.04075635184791221,
#   -0.08374911662198224,
#   -0.024769756123919677,
#   -0.037727646360214126,
#   -0.06098369495310309,
#   0.00699177211810377,
#   0.0023771364650257,
#   0.0003652548980033786,
#   -0.03637583770862187,
#   -0.0017622883205475979,
#   0.00983753231396388,
#   0.0013748130369768063,
#   0.023288668282433672,
#   0.09196962639349078,
#   0.08716985691414555,
#   -0.029350707249950356,
#   -0.016249199879842927,
#   -0.08159566944439109,
#   0.022320006766594132,
#   0.0006547134309176535,
#   0.017858920759174834,
#   0.023963727449205517,
#   0.03255829608084019,
#   -0.06175185837282578,
#   0.046265245016400516,
#   0.004217985913130055,
#   0.006207986521145199,
#   -0.004309845550085155,
#   -0.0028007769512955246,
#   -0.007879584970064607,
#   -0.03055947830127106,
#   -0.056565901107321785,
#   0.044510797966112486,
#   -0.016054054979810998,
#   -0.03607627247106316,
#   -0.014295059251766414,
#   0.005556558532933343,
#   0.027026240892496858,
#   -0.0006171972277027867,
#   0.010092925116099334,
#   0.00023223490406357717,
#   0.009554193731891996,
#   -0.005547205425566861,
#   -0.004322056095516441,
#   0.004344333987776138,
#   0.010197059685973476,
#   -0.0021865857578103995,
#   0.004059921230941052,
#   0.00017190267762055904,
#   0.010099015602841797,
#   -0.0048830844516916565,
#   -0.0061341325972652785,
#   0.006220622707865602,
#   -0.005252063936590611,
#   0.0038004773471926943,
#   -0.0017106050094668067,
#   -0.0023801778188601574,
#   0.014699905520379301,
#   -0.0026102901736975892,
#   0.0009723961853927882,
#   0.0034665367716872676,
#   -0.004891342095393686,
#   0.001861628308944505,
#   -0.004019730278954302,
#   -0.007703943573957428,
#   0.0022532205751132697,
#   -0.0023914557167895516,
#   -0.006804590193713258,
#   0.003291965865929023,
#   0.003826508487155088,
#   0.00045477861372780054,
#   -0.0013743311130449017,
#   0.0003741396119016197,
#   0.0035610168186221407,
#   0.0010880254591395639,
#   0.000781462190082718,
#   0.006935964906439769,
#   -0.0012299877173422933]}

# %% [markdown]
# We'll need to re-convert to PyTorch.

# %%
# reformat dataset lists to torch tensors
opt_dataset.set_format('torch', columns=['energy', 'coords','forces'], output_all_columns=True)
td_dataset.set_format('torch', columns=['energy', 'coords','forces'], output_all_columns=True)

# %%
opt_dataset[0]
# Out:
# {'coords': tensor([-1.7365,  1.3097,  5.1288, -1.5198,  1.1527,  3.7460, -0.6614,  0.3525,
#           3.0057, -0.8821,  0.7326,  1.6502, -0.2310,  0.1866,  0.4400, -0.4846,
#           0.6215, -1.0329,  0.5960, -0.5005, -1.1146,  1.2970,  0.1879,  0.0944,
#          -0.2535, -1.2926, -0.0766, -1.8106,  1.6883,  1.5537, -2.1830,  1.9305,
#           2.8444, -1.0775,  0.7501,  5.6606, -2.6807,  1.0490,  5.4048,  0.0104,
#          -0.4076,  3.3820, -1.4734,  0.3898, -1.4397, -0.1691,  1.6355, -1.2960,
#           1.0740, -0.8972, -2.0142,  1.7470,  1.1697, -0.0845,  1.9392, -0.4433,
#           0.7182,  0.2762, -2.0313,  0.5348, -1.2254, -1.6684, -0.4125, -2.8092,
#           2.6975,  3.0476]),
#  'energy': tensor([-298509.5312]),
#  'forces': tensor([ 8.6516e-03,  9.9962e-03, -2.1068e-02, -6.0739e-02, -7.5098e-02,
#           1.4797e-02,  6.7018e-02,  6.8418e-02,  1.4632e-02, -1.8251e-02,
#          -5.5096e-02,  2.0181e-02, -4.5286e-02,  5.9464e-02, -4.5025e-02,
#          -3.8120e-03, -6.7527e-03,  5.1948e-03,  1.6964e-02, -1.8742e-02,
#           1.5958e-02, -9.8154e-04, -1.6078e-02,  1.2001e-02,  1.6961e-02,
#          -2.6534e-03,  1.7989e-02,  3.2499e-02,  1.3396e-02, -4.8353e-03,
#           1.0469e-02,  3.0785e-02,  2.6514e-02,  6.0428e-03,  2.9176e-05,
#          -1.7213e-03, -2.0643e-03,  1.7799e-03,  1.5479e-02, -2.1843e-02,
#          -2.0284e-02, -4.0345e-04, -2.1869e-03, -1.3649e-04,  1.3552e-03,
#          -1.5717e-03,  2.2467e-05,  3.2304e-04, -1.1443e-02,  1.3375e-02,
#          -6.7546e-03, -3.2093e-03,  8.2927e-04, -3.5246e-03, -1.2859e-03,
#           8.0877e-03,  9.0625e-03, -5.4872e-03,  1.4734e-04,  7.5003e-03,
#           9.4602e-04,  1.4462e-03, -1.9917e-03, -1.4763e-02, -1.5407e-02,
#          -3.4525e-03]),
#  'smiles': '[H:14][C:3]1=[C:2]([N:11]([N:10]=[C:4]1[C:5]23[C:6]([C:7]([C:8]2([H:18])[H:19])([C:9]3([H:20])[H:21])[H:17])([H:15])[H:16])[H:22])[N:1]([H:12])[H:13]'}

# %% [markdown]
# ## Fitting
#
# For how to fit a force field to optimization data from a SMIRNOFF force field, here's an [example I put together for the IRL Irvine meeting](https://openforcefield.atlassian.net/wiki/spaces/MEET/pages/3440508935/Hackathon+How+to+train+your+force+field+with+smee) (`run-smee-fit-from-qca-data-commented.ipynb` where you can largely follow on from the "Assign parameters to molecules in the dataset" heading.
#
# The only note is that the `descent.targets.energy.predict` function would have to be re-written to not include forces in the objective and prediction if they're not in the data.
